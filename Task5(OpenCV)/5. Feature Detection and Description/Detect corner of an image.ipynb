# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('D:\open CV\kitty.jpeg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\o'
# <>:1: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\3 Stars Laptop\AppData\Local\Temp\ipykernel_13148\3486182307.py:1: SyntaxWarning: invalid escape sequence '\o'
#   img = cv2.imread('D:\open CV\kitty.jpeg')

# %%
corners = cv2.goodFeaturesToTrack(
    gray,
    maxCorners=27,
    qualityLevel=0.01,
    minDistance=10,
    blockSize=3,
    useHarrisDetector=False,
    k=0.04
)

# %%
corners = np.intp(corners)  # Convert to integer coords
for corner in corners:
    x, y = corner.ravel()
    cv2.circle(img, (x, y), radius=3, color=(0, 274, 0), thickness=5)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Corners Detected')
plt.axis('off')
plt.show()
